# %%
# run my startup script
exec(open("../src/functions/fun_loadStartup.py").read())
# load my functions
exec(open("../src/functions/fun_loadMyFunctions.py").read())

# %config InlineBackend.figure_format='png'
# Out:
# loaded my modules
# loaded my own functions

# %%
### Load grid
grdFile = '../data/raw/EACouter_varres_grd_mergedBLbry_uhroms.nc'
grid = loadRomsGrid(grdFile)
# Out:
# loading ROMS grid from ../data/raw/EACouter_varres_grd_mergedBLbry_uhroms.nc

# %%
### Set file names
runningLocation = 'local'
if  runningLocation== 'local':
    hisFilePath='../data/raw/'
elif runningLocation == 'gdata':
    hisFilePath='/g/data/fu5/deg581/EAC_2yr_truthRun_obsVerification/output/'
outFilePath='../data/proc/'

# %%
import glob
chunks = {'ocean_time':1}

filelist = glob.glob(hisFilePath+'outer_his_*.nc')

for files in filelist: 
    print(files)
    # filelist.append(files)
ds = xr.open_mfdataset(filelist,chunks, data_vars='minimal',compat='override',coords='minimal',parallel=True, join='right')
# Out:
# ../data/raw/outer_his_08005.nc
# ../data/raw/outer_his_08001.nc
# ../data/raw/outer_his_08009.nc

# %%
# load to some variables:
ssh = ds.zeta
sst = ds.temp.isel(s_rho=-1)
temp = ds.temp
salt = ds.salt
u = ds.u
v = ds.v
# Out:
# <xarray.Dataset>
# Dimensions:     (eta_rho: 317, eta_u: 317, eta_v: 316, ocean_time: 6, s_rho: 30, xi_rho: 272, xi_u: 271, xi_v: 272)
# Coordinates:
#     lon_rho     (eta_rho, xi_rho) float64 dask.array<chunksize=(317, 272), meta=np.ndarray>
#     lat_rho     (eta_rho, xi_rho) float64 dask.array<chunksize=(317, 272), meta=np.ndarray>
#   * ocean_time  (ocean_time) datetime64[ns] 2011-11-28T12:00:00 ... 2011-12-1...
#   * s_rho       (s_rho) float64 -0.9715 -0.9156 -0.8614 ... -0.0156 -0.004799
#     lon_u       (eta_u, xi_u) float64 dask.array<chunksize=(317, 271), meta=np.ndarray>
#     lat_u       (eta_u, xi_u) float64 dask.array<chunksize=(317, 271), meta=np.ndarray>
#     lon_v       (eta_v, xi_v) float64 dask.array<chunksize=(316, 272), meta=np.ndarray>
#     lat_v       (eta_v, xi_v) float64 dask.array<chunksize=(316, 272), meta=np.ndarray>
# Dimensions without coordinates: eta_rho, eta_u, eta_v, xi_rho, xi_u, xi_v
# Data variables:
#     zeta        (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(1, 317, 272), meta=np.ndarray>
#     sst         (ocean_time, eta_rho, xi_rho) float32 dask.array<chunksize=(1, 317, 272), meta=np.ndarray>
#     temp        (ocean_time, s_rho, eta_rho, xi_rho) float32 dask.array<chunksize=(1, 30, 317, 272), meta=np.ndarray>
#     salt        (ocean_time, s_rho, eta_rho, xi_rho) float32 dask.array<chunksize=(1, 30, 317, 272), meta=np.ndarray>
#     u           (ocean_time, s_rho, eta_u, xi_u) float32 dask.array<chunksize=(1, 30, 317, 271), meta=np.ndarray>
#     v           (ocean_time, s_rho, eta_v, xi_v) float32 dask.array<chunksize=(1, 30, 316, 272), meta=np.ndarray>

# %%
## save ds to output netcdf

out = ssh.to_dataset()
out['sst'] = sst
out['temp'] = temp
out['salt'] = salt
out['u'] = u
out['v'] = v

out.to_netcdf(path = outFilePath+'truth.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/dave/Documents/dave/Projects/OSSE-analysis/data/proc/truth.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-18-3bf557f96996> in <module>
#       8 out['v'] = v
#       9
# ---> 10 out.to_netcdf(path = outFilePath+'truth.nc')
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1797         from ..backends.api import to_netcdf
#    1798
# -> 1799         return to_netcdf(
#    1800             self,
#    1801             path,
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1057                 f"unrecognized option 'invalid_netcdf' for engine {engine}"
#    1058             )
# -> 1059     store = store_open(target, mode, format, group, **kwargs)
#    1060
#    1061     if unlimited_dims is None:
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     378             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     379         )
# --> 380         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     381
#     382     def _acquire(self, needs_lock=True):
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     326         self._group = group
#     327         self._mode = mode
# --> 328         self.format = self.ds.data_model
#     329         self._filename = self.ds.filepath()
#     330         self.is_remote = is_remote_uri(self._filename)
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     387     @property
#     388     def ds(self):
# --> 389         return self._acquire()
#     390
#     391     def open_store_variable(self, name, var):
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     381
#     382     def _acquire(self, needs_lock=True):
# --> 383         with self._manager.acquire_context(needs_lock) as root:
#     384             ds = _nc4_require_group(root, self._group, self._mode)
#     385         return ds
#
# ~/miniconda3/envs/devel/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/miniconda3/envs/devel/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'/Users/dave/Documents/dave/Projects/OSSE-analysis/data/proc/truth.nc'
